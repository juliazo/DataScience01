# %% [markdown]
# # Reto
# 1. Ahora repite el reto usando Scrapy: (Nombre del producto, Precio, Precio de descuento, número de ventas)
# 2. Usa los selectores que gustes
# 3. Exporta el archivo a csv
# 4. Importa el archivo csv a tu libreta de jupyter.

# %%
#Importamos el archivo que genero la araña y hacemos un dataframe
import pandas as pd
mercadolibre = pd.read_csv("gasolina.csv")

# %%
mercadolibre
# Out:
#            Marca     Submarca                                        Versión  \
# 0           FORD       FUSION         HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (CVT)
# 1           FORD       FUSION        HIBRIDO 4PTS 2.0L 4CIL 188HP AUT (eCVT)
# 2           FORD       FUSION  HIBRIDO 4X2 4PTAS 2.0L 4CIL 141(+47e)HP E-CVT
# 3           FORD       FUSION         HIBRIDO 4PTAS 2.0L 4CIL 188HP AUT eCVT
# 4           FORD       FUSION                HYBRID 4PTS 2.5L 4CIL 156HP CVT
# ...          ...          ...                                            ...
# 4612  LAND ROVER  RANGE ROVER               SUPERCARGADA 5PTS 5.0L 506HP AUT
# 4613  LAND ROVER  RANGE ROVER          SUPERCARGADA 5PTS 5.0L 8CIL 506HP AUT
# 4614    MERCEDES         G 65     AMG 4X4 5PTAS 6.0L 12CIL 630HP AUT BITURBO
# 4615    MERCEDES         G 65         AMG 5PTAS 6.0L 12CIL 630HP BITURBO AUT
# 4616    MERCEDES     ML63 AMG                       5PTS 6.2L 8CIL 503HP AUT
#
# ...

# %%
dftowork = mercadolibre.groupby(['Marca'], sort=True)['CO2(g/km)'].max()

# %%
dftowork
# Out:
# Marca
# FORD           404.0
# HONDA          353.0
# SEAT           246.0
# MAZDA          351.0
# CHEVROLET      416.0
# VW             410.0
# SUZUKI         274.0
# NISSAN         403.0
# HYUNDAI        371.0
# FIAT           317.0
# MITSUBISHI     368.0
# KIA            281.0
# MERCEDES       584.0
# DODGE          423.0
# RENAULT        309.0
# PEUGEOT        302.0
# TOYOTA         493.0
# BMW            407.0
# AUDI           449.0
# MINI           242.0
# SUBARU         320.0
# INFINITI       386.0
# VOLVO          347.0
# ALFA ROMEO     368.0
# PORSCHE        532.0
# ACURA          354.0
# CADILLAC       400.0
# CHRYSLER       357.0
# LINCOLN        493.0
# BUICK          332.0
# SAAB           328.0
# LEXUS          333.0
# JAGUAR         487.0
# BENTLEY        627.0
# ROLLSROYCE     492.0
# MAYBACH        477.0
# LAMBORGHINI    615.0
# SMART          159.0
# LAND ROVER     446.0
# GML            240.0
# JEEP           452.0
# MERCURY        262.0
# GMC            400.0
# ...

# %% [markdown]
# # Otros sitios Scrapping
# Aeropuerto Ciudad de México
#
# http://www.ift.org.mx  (Para descargar datos ya hecho)
#
# Despegar.com.mx
#
# Trivago.com.mx
#
# Coneval (Datos procesados)
#
# http://premio.ceneval.edu.mx/premio_egel/index.jsf (Scrappear texto limpio y filtrado)
#
# VivaAerobus.com

# %%
dftowork.groupby(['CO2(g/km)'], sort=False)['count'].max()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-7dca15e635a6> in <module>
# ----> 1 dftowork.groupby(['CO2(g/km)'], sort=False)['count'].max()
#
# D:\Users\davincy\Anaconda3\envs\DataScience\lib\site-packages\pandas\core\series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    1686             group_keys=group_keys,
#    1687             squeeze=squeeze,
# -> 1688             observed=observed,
#    1689         )
#    1690
#
# D:\Users\davincy\Anaconda3\envs\DataScience\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.barplot(dftowork['CO2(g/km)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Users\davincy\Anaconda3\envs\DataScience\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4410             try:
# -> 4411                 return libindex.get_value_at(s, key)
#    4412             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.get_value_at()
#
# pandas\_libs\util.pxd in pandas._libs.util.validate_indexer()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-153ede51d560> in <module>
#       1 import matplotlib.pyplot as plt
# ...

# %%
dftowork.head()
# Out:
# Marca
# FORD         404.0
# HONDA        353.0
# SEAT         246.0
# MAZDA        351.0
# CHEVROLET    416.0
# Name: CO2(g/km), dtype: float64
