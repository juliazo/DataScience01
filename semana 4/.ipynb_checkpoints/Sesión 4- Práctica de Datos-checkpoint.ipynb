# %% [markdown]
# ## *Sesión de retos*
#
# ### Objetivo de la Sesión 4:
#
# * Explorar el *set* de datos de la iniciativa 3de3.
# * Elegir un reto y proponer una solución.
#
# ### *“Trabajar en equipo, divide el trabajo y multiplica los resultados”*, Anónimo.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Introducción a un set de datos reales Iniciativa #3de3
#
#
# Bajar el set de datos la iniciativa #3de3
#
# Descargar información de https://www.3de3.mx/datos_abiertos

# %%
import requests
import pandas as pd


#declarantes_json = requests.get("https://3de3.mx/declarantes.json?by_federal_entity=Ciudad de&declarant_type=public_servent")

#declarantes = pd.DataFrame(declarantes_json.json())
#declarantes

# %%
#requests.get("https://3de3.mx/declarantes/4918.json?declarant_type=public_servant").json()

# %% [markdown]
# 1. Descargar las primeras 4 páginas
# 2. Agregar columna de género
# 3. Agregar columna de entidad

# %% [markdown]
# Ejercicio extra de la semana 4 Julio Ontiveros

# %%
#the api is kind of glitchy i got a litle confused because in the first part it 
#asks us to download the first 4 questions and after that it asks us the total of participants
#anyway i wrote this that actually works and can download ALL the data of the api even with the "glitchiness?? :)"
#wich i am going to explain step by step

#i made this recursive function the thing is the api wasnt always avaylable it returned 200ok but no json
#putting the url in the browser i notice that time to time it returned "Retry later" and the i noticed when i put a page that
#doesnt exists it returned 404 so i made this recursive to keep trying if it returns "Retry Later"
def jsonParse(url):
    try_number = 1
    page_json = requests.get(url)
    if (page_json):
        page_panda = pd.DataFrame(page_json.json())
        if page_json.text == "Retry later":
            jsonParse(url)
        else:
            return page_panda
    else:
        if try_number < 10: #this is to take the 4
            try_number = try_number + 1
        return False
    
#the json doesnt come with the columns you are asking it doesnt either have the index of the values of the parameters
#so we can consult so the partys was the copy paste of the list in the page and the states i just typed them it seems to work
#well then i made the 3 lists and then iterate first by gender then by party then by state by just commnet the 'break' and get
#all the data
declarantes = pd.DataFrame()
genders = ['F','M']
states = ['Aguascalientes','Baja California','Baja California Sur','Campeche','Coahuila','Colima','Chiapas','Chihuahua','Ciudad de','Durango','Guanajuato','Guerrero','Hidalgo','Jalisco','Mexico','Michoacan','Morelos','Nayarit','Nuevo Leon','Oaxaca','Puebla','Queretaro','Quintana Roo','San Luis Potosi','Sinaloa','Sonora','Tabasco','Tamaulipas','Tlaxcala','Veracruz','Yucatan','Zacatecas']
parties = ['PRI', 'PAN', 'PT', 'PVEM', 'PRD', 'MC', 'Nueva Alianza', 'Morena', 'PH', 'PES', 'Otro', 'Independiente']
for state in states:
    for party in parties:
        for gender in genders:
            arepages = True
            x = 1
            while(arepages): 
                page_panda = jsonParse("https://3de3.mx/declarantes.json?page={}&by_gender={}&by_federal_entity={}&by_political_party={}&declarant_type=public_servant".format(str(x),gender,state,party))
                if isinstance(page_panda,pd.DataFrame):
                    print("Cargando Pagina {} {} {} {}".format(str(x),gender,state,party))
                    page_panda['gender'] = gender
                    page_panda['federal_entity'] = state
                    page_panda['political_party'] = party
                    declarantes = declarantes.append([page_panda],ignore_index = True)
                    x = x + 1
                    break #comment this line to get all the data fron the api
                else:
                    arepages = False
   
declarantes
# Out:
# Cargando Pagina 1 F Aguascalientes PRI
# Cargando Pagina 1 M Aguascalientes PRI
# Cargando Pagina 1 F Aguascalientes PAN
# Cargando Pagina 1 M Aguascalientes PAN
# Cargando Pagina 1 F Aguascalientes PT
# Cargando Pagina 1 M Aguascalientes PT
# Cargando Pagina 1 F Aguascalientes PVEM
# Cargando Pagina 1 M Aguascalientes PVEM
# Cargando Pagina 1 F Aguascalientes PRD
# Cargando Pagina 1 M Aguascalientes PRD
# Cargando Pagina 1 F Baja California MC
# Cargando Pagina 1 M Baja California MC
# Cargando Pagina 1 F Baja California Nueva Alianza
# Cargando Pagina 1 M Baja California Nueva Alianza
# Cargando Pagina 1 F Baja California Morena
# Cargando Pagina 1 M Baja California Morena
# Cargando Pagina 1 F Baja California PH
# Cargando Pagina 1 M Baja California PH
# Cargando Pagina 1 F Baja California PES
# Cargando Pagina 1 M Baja California PES
# Cargando Pagina 1 M Campeche PT
# Cargando Pagina 1 F Campeche PVEM
# Cargando Pagina 1 M Campeche PVEM
# Cargando Pagina 1 F Campeche PRD
# Cargando Pagina 1 M Campeche PRD
# Cargando Pagina 1 F Campeche MC
# Cargando Pagina 1 M Campeche MC
# Cargando Pagina 1 F Campeche Nueva Alianza
# Cargando Pagina 1 M Campeche Nueva Alianza
# Cargando Pagina 1 F Campeche Morena
# Cargando Pagina 1 F Colima PRI
# Cargando Pagina 1 M Colima PRI
# Cargando Pagina 1 F Colima PAN
# Cargando Pagina 1 M Colima PAN
# Cargando Pagina 1 F Colima PT
# Cargando Pagina 1 M Colima PT
# Cargando Pagina 1 F Colima PVEM
# Cargando Pagina 1 M Colima PVEM
# Cargando Pagina 1 F Colima PRD
# Cargando Pagina 1 M Colima PRD
# Cargando Pagina 1 M Chiapas PES
# Cargando Pagina 1 F Chiapas Otro
# Cargando Pagina 1 M Chiapas Otro
# Cargando Pagina 1 F Chiapas Independiente
# Cargando Pagina 1 M Chiapas Independiente
# Cargando Pagina 1 F Chihuahua PRI
# Cargando Pagina 1 M Chihuahua PRI
# Cargando Pagina 1 F Chihuahua PAN
# Cargando Pagina 1 M Chihuahua PAN
# Cargando Pagina 1 F Chihuahua PT
# Cargando Pagina 1 F Ciudad de Nueva Alianza
# Cargando Pagina 1 M Ciudad de Nueva Alianza
# Cargando Pagina 1 F Ciudad de Morena
# Cargando Pagina 1 M Ciudad de Morena
# Cargando Pagina 1 F Ciudad de PH
# Cargando Pagina 1 M Ciudad de PH
# Cargando Pagina 1 F Ciudad de PES
# Cargando Pagina 1 M Ciudad de PES
# Cargando Pagina 1 F Ciudad de Otro
# Cargando Pagina 1 M Ciudad de Otro
# Cargando Pagina 1 F Guanajuato PT
# Cargando Pagina 1 M Guanajuato PT
# Cargando Pagina 1 F Guanajuato PVEM
# Cargando Pagina 1 M Guanajuato PVEM
# Cargando Pagina 1 F Guanajuato PRD
# Cargando Pagina 1 M Guanajuato PRD
# Cargando Pagina 1 F Guanajuato MC
# Cargando Pagina 1 M Guanajuato MC
# Cargando Pagina 1 F Guanajuato Nueva Alianza
# Cargando Pagina 1 M Guanajuato Nueva Alianza
# Cargando Pagina 1 M Guerrero Independiente
# Cargando Pagina 1 F Hidalgo PRI
# Cargando Pagina 1 M Hidalgo PRI
# Cargando Pagina 1 F Hidalgo PAN
# Cargando Pagina 1 M Hidalgo PAN
# Cargando Pagina 1 F Hidalgo PT
# Cargando Pagina 1 M Hidalgo PT
# Cargando Pagina 1 F Hidalgo PVEM
# Cargando Pagina 1 M Hidalgo PVEM
# Cargando Pagina 1 F Hidalgo PRD
# Cargando Pagina 1 M Jalisco PES
# Cargando Pagina 1 F Jalisco Otro
# Cargando Pagina 1 M Jalisco Otro
# Cargando Pagina 1 F Jalisco Independiente
# Cargando Pagina 1 M Jalisco Independiente
# Cargando Pagina 1 F Mexico PRI
# Cargando Pagina 1 M Mexico PRI
# Cargando Pagina 1 F Mexico PAN
# Cargando Pagina 1 M Mexico PAN
# Cargando Pagina 1 F Mexico PT
# Cargando Pagina 1 F Michoacan Nueva Alianza
# Cargando Pagina 1 M Michoacan Nueva Alianza
# Cargando Pagina 1 F Michoacan Morena
# Cargando Pagina 1 M Michoacan Morena
# Cargando Pagina 1 F Michoacan PH
# Cargando Pagina 1 M Michoacan PH
# Cargando Pagina 1 F Michoacan PES
# Cargando Pagina 1 M Michoacan PES
# Cargando Pagina 1 F Michoacan Otro
# Cargando Pagina 1 M Michoacan Otro
# Cargando Pagina 1 M Nayarit PVEM
# Cargando Pagina 1 F Nayarit PRD
# Cargando Pagina 1 M Nayarit PRD
# Cargando Pagina 1 F Nayarit MC
# Cargando Pagina 1 M Nayarit MC
# Cargando Pagina 1 F Nayarit Nueva Alianza
# Cargando Pagina 1 M Nayarit Nueva Alianza
# Cargando Pagina 1 F Nayarit Morena
# Cargando Pagina 1 M Nayarit Morena
# Cargando Pagina 1 F Nayarit PH
# Cargando Pagina 1 F Oaxaca PAN
# Cargando Pagina 1 M Oaxaca PAN
# Cargando Pagina 1 F Oaxaca PT
# Cargando Pagina 1 M Oaxaca PT
# Cargando Pagina 1 F Oaxaca PVEM
# Cargando Pagina 1 M Oaxaca PVEM
# Cargando Pagina 1 F Oaxaca PRD
# Cargando Pagina 1 M Oaxaca PRD
# Cargando Pagina 1 F Oaxaca MC
# Cargando Pagina 1 M Oaxaca MC
# Cargando Pagina 1 F Puebla PES
# Cargando Pagina 1 M Puebla PES
# Cargando Pagina 1 F Puebla Otro
# Cargando Pagina 1 M Puebla Otro
# Cargando Pagina 1 F Puebla Independiente
# Cargando Pagina 1 M Puebla Independiente
# Cargando Pagina 1 F Queretaro PRI
# Cargando Pagina 1 M Queretaro PRI
# Cargando Pagina 1 F Queretaro PAN
# Cargando Pagina 1 M Queretaro PAN
# Cargando Pagina 1 M Quintana Roo MC
# Cargando Pagina 1 F Quintana Roo Nueva Alianza
# Cargando Pagina 1 M Quintana Roo Nueva Alianza
# Cargando Pagina 1 F Quintana Roo Morena
# Cargando Pagina 1 M Quintana Roo Morena
# Cargando Pagina 1 F Quintana Roo PH
# Cargando Pagina 1 M Quintana Roo PH
# Cargando Pagina 1 F Quintana Roo PES
# Cargando Pagina 1 M Quintana Roo PES
# Cargando Pagina 1 F Quintana Roo Otro
# Cargando Pagina 1 F Sinaloa PVEM
# Cargando Pagina 1 M Sinaloa PVEM
# Cargando Pagina 1 F Sinaloa PRD
# Cargando Pagina 1 M Sinaloa PRD
# Cargando Pagina 1 F Sinaloa MC
# Cargando Pagina 1 M Sinaloa MC
# Cargando Pagina 1 F Sinaloa Nueva Alianza
# Cargando Pagina 1 M Sinaloa Nueva Alianza
# Cargando Pagina 1 F Sinaloa Morena
# Cargando Pagina 1 M Sinaloa Morena
# Cargando Pagina 1 F Sonora Independiente
# Cargando Pagina 1 M Sonora Independiente
# Cargando Pagina 1 F Tabasco PRI
# Cargando Pagina 1 M Tabasco PRI
# Cargando Pagina 1 F Tabasco PAN
# Cargando Pagina 1 M Tabasco PAN
# Cargando Pagina 1 F Tabasco PT
# Cargando Pagina 1 M Tabasco PT
# Cargando Pagina 1 F Tabasco PVEM
# Cargando Pagina 1 M Tabasco PVEM
# Cargando Pagina 1 M Tamaulipas PH
# Cargando Pagina 1 F Tamaulipas PES
# Cargando Pagina 1 M Tamaulipas PES
# Cargando Pagina 1 F Tamaulipas Otro
# Cargando Pagina 1 M Tamaulipas Otro
# Cargando Pagina 1 F Tamaulipas Independiente
# Cargando Pagina 1 M Tamaulipas Independiente
# Cargando Pagina 1 F Tlaxcala PRI
# Cargando Pagina 1 M Tlaxcala PRI
# Cargando Pagina 1 F Tlaxcala PAN
# Cargando Pagina 1 M Veracruz MC
# Cargando Pagina 1 F Veracruz Nueva Alianza
# Cargando Pagina 1 M Veracruz Nueva Alianza
# Cargando Pagina 1 F Veracruz Morena
# Cargando Pagina 1 M Veracruz Morena
# Cargando Pagina 1 F Veracruz PH
# Cargando Pagina 1 M Veracruz PH
# Cargando Pagina 1 F Veracruz PES
# Cargando Pagina 1 M Veracruz PES
# Cargando Pagina 1 F Veracruz Otro
# Cargando Pagina 1 F Zacatecas PVEM
# Cargando Pagina 1 M Zacatecas PVEM
# Cargando Pagina 1 F Zacatecas PRD
# Cargando Pagina 1 M Zacatecas PRD
# Cargando Pagina 1 F Zacatecas MC
# Cargando Pagina 1 M Zacatecas MC
# Cargando Pagina 1 F Zacatecas Nueva Alianza
# Cargando Pagina 1 M Zacatecas Nueva Alianza
# Cargando Pagina 1 F Zacatecas Morena
# Cargando Pagina 1 M Zacatecas Morena
#          id      first_name              last_name          twitter  \
# 0     751.0           María  Alemán Muñoz Castillo     MariaAlemanM
# 1    5040.0  Ivonne Liliana         Álvarez García   alvarez_ivonne
# 2     957.0           Hazel       Montejano García   hazelmontejano
# 3    4918.0  Martha Cecilia       Márquez Alvarado   mmarthamarquez
# 4    5055.0    Martha Elisa       González Estrada     MarthaGlzAgs
# ..      ...             ...                    ...              ...
# 349  5041.0       Miroslava         Sánchez Galván  DiputadosMorena
# 350  4958.0            José         Narro Céspedes         JosNarro
# 351  6406.0            Saúl          Monreal Ávila     saul_monreal
# 352  6404.0     Julio César         Chávez Padilla    juliocesarchp
# 353  6405.0          Ulises             Mejía Haro    UlisesMejiaH_
#
#              position                                          interests  \
# 0    Diputado federal  {'document_link': 'https://s3-us-west-1.amazon...
# 1    Diputado federal  {'document_link': 'https://s3-us-west-1.amazon...
# 2             Regidor  {'document_link': 'https://s3-us-west-1.amazon...
# 3             Senador  {'document_link': 'https://s3-us-west-1.amazon...
# 4    Diputado federal  {'document_link': 'https://s3-us-west-1.amazon...
# ..                ...                                                ...
# 349  Diputado federal  {'document_link': 'https://s3-us-west-1.amazon...
# 350           Senador  {'document_link': 'https://s3-us-west-1.amazon...
# 351           Alcalde  {'document_link': 'https://s3-us-west-1.amazon...
# 352           Alcalde  {'document_link': 'https://s3-us-west-1.amazon...
# 353           Alcalde  {'document_link': 'https://s3-us-west-1.amazon...
#
#                                              ownership  \
# 0    {'document_link': 'https://s3-us-west-1.amazon...
# 1    {'document_link': 'https://s3-us-west-1.amazon...
# 2    {'document_link': 'https://s3-us-west-1.amazon...
# 3    {'document_link': 'https://s3-us-west-1.amazon...
# 4    {'document_link': 'https://s3-us-west-1.amazon...
# ..                                                 ...
# 349  {'document_link': 'https://s3-us-west-1.amazon...
# 350  {'document_link': 'https://s3-us-west-1.amazon...
# 351  {'document_link': 'https://s3-us-west-1.amazon...
# 352  {'document_link': 'https://s3-us-west-1.amazon...
# 353  {'document_link': 'https://s3-us-west-1.amazon...
#
#                                                 fiscal Genero         Entidad  \
# 0    {'document_link': 'https://s3-us-west-1.amazon...      F  Aguascalientes
# 1    {'document_link': 'https://s3-us-west-1.amazon...      F  Aguascalientes
# 2    {'document_link': 'https://s3-us-west-1.amazon...      F  Aguascalientes
# 3    {'document_link': 'https://s3-us-west-1.amazon...      F  Aguascalientes
# 4    {'document_link': 'https://s3-us-west-1.amazon...      F  Aguascalientes
# ..                                                 ...    ...             ...
# 349  {'document_link': 'https://s3-us-west-1.amazon...      F       Zacatecas
# 350  {'document_link': 'https://s3-us-west-1.amazon...      M       Zacatecas
# 351  {'document_link': 'https://s3-us-west-1.amazon...      M       Zacatecas
# 352  {'document_link': 'https://s3-us-west-1.amazon...      M       Zacatecas
# 353  {'document_link': 'https://s3-us-west-1.amazon...      M       Zacatecas
#
#     Partido
# 0       PRI
# 1       PRI
# 2       PRI
# 3       PAN
# 4       PAN
# ..      ...
# 349  Morena
# 350  Morena
# 351  Morena
# 352  Morena
# 353  Morena
#
# [354 rows x 11 columns]

# %% [markdown]
# ### Número total funcionarios en #3de3

# %%
funcionarios = len(declarantes.index)
print ("Hay {} funcionarios".format(funcionarios))
# Out:
# Hay 354 funcionarios

# %% [markdown]
# ### Participación en #3de3 por género

# %%
declarantes.groupby(["Genero"]).size()
# Out:
# Genero
# F    150
# M    204
# dtype: int64

# %% [markdown]
# ### Numero de funcionarios por partido

# %%
declarantes.groupby(["Partido"]).size()
# Out:
# Partido
# Independiente      1
# MC                20
# Morena            90
# Nueva Alianza      5
# Otro               5
# PAN              123
# PES               21
# PRD               21
# PRI               53
# PT                 8
# PVEM               7
# dtype: int64

# %% [markdown]
# # 3. Retos (opcional)
#
# - Random Walk
#
# - Game of Life
#
# - Imagenes
#
# - Texto

# %% [markdown]
# # 4. Conclusiones
# - ¿Qué se llevan de esta semana?
# - ¿Qué áreas encontraron de oportunidad en ustedes?
# - ¿Qué les hubiera gustado ver en esta semana?
